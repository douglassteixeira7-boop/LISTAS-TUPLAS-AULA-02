# %% [markdown]
# <a href="https://colab.research.google.com/github/douglassteixeira7-boop/LISTAS-TUPLAS-AULA-02/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # Isto está formatado como código
# ```

# %% [markdown]
# questao 1

# %%
nome = "Douglas Da Silva Teixeira"
idade = "32 anos"
profissao = "Analista"
print(nome)
print(idade)
print(profissao)
# Out:
# Douglas Da Silva Teixeira
# 32 anos
# Analista

# %% [markdown]
# quetao 2

# %%
produto = "Notebook"
marca = "Dell"
preco = 450000
print(produto)
print(marca)
print(preco)
# Out:
# Notebook
# Dell
# R$ 4.500,00

# %% [markdown]
# Questão 3

# %%
numero1= 12
numero2= 6
soma= numero1 + numero2
sub= numero1 - numero2
mult= numero1 * numero2
divisao= int(numero1 / numero2)

print("numero 1:",numero1)
print("numero 2:",numero2)
print("soma:",soma)
print("subtração:",sub)
print("multiplicação:",mult)
print("divisão:",divisao)
# Out:
# numero 1: 12
# numero 2: 6
# soma: 18
# subtração: 6
# multiplicação: 72
# divisão: 2

# %% [markdown]
# Q4

# %%
num1= 7
num2= 2
soma= num1+num2
sub= num1-num2
multi= num1*num2
divisao= num1/num2
poten= num1**num2
print("soma",soma)
print("subtração",sub)
print("multiplicação",multi)
print("divisão",divisao)
print("**",poten)
# Out:
# soma 9
# subtração 5
# multiplicação 14
# divisão 3.5
# ** 49

# %% [markdown]
# Q5

# %%
num1=15
num2=5
soma= num1+num2
sub= num1-num2
mult=num1*num2
div=num1/num2
pot=num1**num2
print("soma",soma)
print("subtração",sub)
print("multiplicação",mult)
print("divisão",div)
print("potenciação",pot)
# Out:
# soma 20
# subtração 10
# multiplicação 75
# divisão 3.0
# potenciação 759375

# %% [markdown]
# Q
