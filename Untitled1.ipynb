# %% [markdown]
# <a href="https://colab.research.google.com/github/douglassteixeira7-boop/LISTAS-TUPLAS-AULA-02/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LISTAS TUPLAS AT1

# %%
materias=['matemática','histórias','biologia']
notas=(8.5,7.0,9.2)
info={'nome':'Douglas','idade':32,'curso':'Engenharia'}
print("INFORMAÇÃOS",info)
print("Materias",materias)
print("Notas",notas)
# Out:
# INFORMAÇÃOS {'nome': 'Douglas', 'idade': 32, 'curso': 'Engenharia'}
# Materias ['matemática', 'histórias', 'biologia']
# Notas (8.5, 7.0, 9.2)

# %% [markdown]
# AT2

# %%
listas= ['volante','motor','cambio']
especificacoes=('400 cavalos','40 litros')
carro={'Marca':'Ford','Modelo':'Ford KA','Ano':'2026'}
print('Peças','\n',listas)
print('Carro','\n',especificacoes)
print('Dados','\n', carro)
# Out:
# Peças
#  ['volante', 'motor', 'cambio']
# Carro
#  ('400 cavalos', '40 litros')
# Dados
#  {'Marca': 'Ford', 'Modelo': 'Ford KA', 'Ano': '2026'}

# %% [markdown]
# AT3

# %%
categorias=['picanha', 'macies','suculencia']
especificacoes=('preço':'R$120')
