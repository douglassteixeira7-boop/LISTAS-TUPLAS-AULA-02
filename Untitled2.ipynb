# %% [markdown]
# <a href="https://colab.research.google.com/github/douglassteixeira7-boop/LISTAS-TUPLAS-AULA-02/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("8 é maior que 6:",8>6)
print("8 é menor que 7:",8<7)
print(8==7)
print(10>=10)
print(10<10)
print(10<=10)
# Out:
# 8 é maior que 6: True
# 8 é menor que 7: False
# False
# True
# False
# True

# %%
idade=int(input("Digite sua idade:"))
idade2=int(input("Digite sua idade:"))
print(idade==idade)
print(idade!=idade2)
print(idade>idade2)
print(idade>=idade2)
print(idade<=idade2)
# Out:
# Digite sua idade:20
# Digite sua idade:30
# True
# True
# False
# False
# True

# %%
idade=int(input("Digite sua idade"))
convite=input("Tem convite? (sim/não)")
resultado=(idade>=18) and (convite=="sim")
print(resultado)
# Out:
# Digite sua idade32
# Tem convite? (sim/não)sim
# True

# %%
usuario= input("Digite seu usuario:")
senha=input("Digite sua senha:")
resultado=(usuario== "admin")and(senha=="1234")
print(resultado)
# Out:
# Digite seu usuario:admin
# Digite sua senha:1234
# True

# %%
# Out:
#   File "/tmp/ipykernel_30038/454792343.py", line 3
#     print(resultado')
#                    ^
# SyntaxError: unterminated string literal (detected at line 3)
